# %% [markdown]
# Q.1. Refer to googleplaystore.csv file and solve following questions
# 1. Display First 5 records from Dataframe.
# 2. Display category with highest number of apps registered.
# 3. What is the average rating for all the apps
# 4. Display total number of apps which even supports Andriod version 2.3 and up
# 5. Impute the missing values available in rating column with respective measure
# of central tendency.

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/chait/OneDrive/Desktop/FBS/Data Analysis/Datasets/Datasets/googleplaystore.csv")
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
highest_category = data['Category'].value_counts().idxmax()
highest_category
# Out:
# 'FAMILY'

# %%
avg_rate = data['Rating'].mean()
avg_rate
# Out:
# np.float64(4.193338315362443)

# %%
total_app = data[data['Android Ver'].str.contains('2.3 and up',na=False)]
total_app
# Out:
#                                                    App        Category  \
# 5                           Paper flowers instructions  ART_AND_DESIGN
# 14     3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN
# 17                            350 Diy Room Decor Ideas  ART_AND_DESIGN
# 28                               Pencil Sketch Drawing  ART_AND_DESIGN
# 29                     Easy Realistic Drawing Tutorial  ART_AND_DESIGN
# ...                                                ...             ...
# 10770               Modern Counter Terrorist FPS Shoot            GAME
# 10776                                 Monster Ride Pro            GAME
# 10785                                     sugar, sugar          FAMILY
# 10804                                     Poker Pro.Fr            GAME
# 10808                               lesparticuliers.fr       LIFESTYLE
#
#        Rating Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
data['Rating'] = data['Rating'].fillna(data['Rating'].median())
data['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    4.3
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64
