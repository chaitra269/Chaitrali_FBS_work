# %% [markdown]
# Q.14. Find the row-wise and column-wise sums.

# %%
import numpy as np

# %%
arr = np.random.randint(1, 50, size=(4, 4))
arr
# Out:
# array([[15,  4, 17, 31],
#        [42,  3, 47, 11],
#        [49,  1, 27, 27],
#        [16, 31, 46, 28]], dtype=int32)

# %% [raw]
# row_sum = np.sum(arr,axis)
# row_sum

# %%
col_sum = np.sum(arr,axis=0)
col_sum
# Out:
# array([122,  39, 137,  97])
