# %% [markdown]
# Q.15. Generate an array of 10 random integers between 1 and 50.

# %%
import numpy as np

# %%
arr = np.random.randint(1,51,size=(10))
arr
# Out:
# array([40, 12,  4, 46, 23, 32, 16, 40, 50,  8], dtype=int32)
