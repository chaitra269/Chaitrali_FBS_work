# %% [markdown]
# Q.11. Find the transpose of matrix A and matrix B.

# %%
import numpy as np

# %%
A = np.array([[7,4], [3, 4]])
A
# Out:
# array([[7, 4],
#        [3, 4]])

# %%
B = np.array([[2, 6], [7, 9]])
B
# Out:
# array([[2, 6],
#        [7, 9]])

# %%
transpose_a = np.transpose(A)
transpose_a
# Out:
# array([[7, 3],
#        [4, 4]])

# %%
transpose_b = np.transpose(B)
transpose_b
# Out:
# array([[2, 7],
#        [6, 9]])
