# %% [markdown]
# Q.16. Generate a 5x5 matrix of random floats between 0 and 1.

# %%
import numpy as np

# %%
arr = np.random.rand(5, 5)
arr
# Out:
# array([[0.90206262, 0.88430318, 0.14259519, 0.73480955, 0.50662585],
#        [0.77319737, 0.351333  , 0.29524934, 0.25000911, 0.66584281],
#        [0.78880547, 0.61259589, 0.60934127, 0.82164273, 0.39191296],
#        [0.45390522, 0.82016033, 0.84622082, 0.36061162, 0.82190184],
#        [0.84047039, 0.16343109, 0.86332647, 0.60826367, 0.62535977]])
