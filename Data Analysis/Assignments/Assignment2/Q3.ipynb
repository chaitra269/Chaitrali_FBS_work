# %% [markdown]
# Q.3. Create a 2D array (3x3) with values ranging from 0 to 8.

# %%
import numpy as np

# %%
arr = np.arange(9).reshape(3,3)
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5],
#        [6, 7, 8]])
