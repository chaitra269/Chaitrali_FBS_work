# %% [markdown]
# 4. Given a 2D array, find its shape and size. Create a 5x4 array with random integers between
# 1 and 100, and print the shape and size.

# %%
import numpy as np

# %%
arr_2d = np.random.randint(1,101,size=(5,4))
arr_2d
# Out:
# array([[75, 31, 19, 30],
#        [72, 69, 13, 53],
#        [68, 46,  5, 52],
#        [58, 34, 36, 99],
#        [22, 31, 44, 55]], dtype=int32)

# %%
arr_2d.shape
# Out:
# (5, 4)

# %%
arr_2d.size
# Out:
# 20
